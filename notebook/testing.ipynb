# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
columns = [
    'Nomor peserta', 'Nomor keluarga', 'Bobot', 'ID Kunjungan FKTP', 'Tanggal datang kunjungan FKTP',
    'Tanggal pulang kunjungan FKTP', 'Provinsi FKTP', 'Kabupaten/Kota FKTP', 'Kepemilikan FKTP', 'Jenis FKTP',
    'Tipe FKTP', 'Tingkat Pelayanan FKTP', 'Jenis Poli FKTP', 'Segmen Peserta saat akses layanan FKTP',
    'Kode dan nama diagnosis ICD 10 (3 digit)', 'Kode diagnosis ICD 10 (3 digit)', 'Kode diagnosis (beragam 3-5 digit)',
    'Nama diagnosis berasal dari kode diagnosis FKP15', 'Provinsi faskes tujuan rujukan',
    'Kabupaten/Kota faskes tujuan rujukan', 'Kepemilikan faskes tujuan rujukan', 'Jenis faskes tujuan rujukan',
    'Tipe faskes tujuan rujukan', 'Poli faskes tujuan rujukan', 'Jenis Kunjungan FKTP', 'Kelas Status Pulang Peserta'
]
df = pd.read_csv('dataset/train_fktp.txt', names = columns)

# %%
df.head()
# Out:
#    Nomor peserta  Nomor keluarga       Bobot ID Kunjungan FKTP
# 0    157978748.0        50765420   20.064983         958073632  \
# 1     95085112.0        26931775    2.626307  449590620P000054
# 2    224470578.0       227368233    1.051830  467490619P000001
# 3     63871289.0        62313678  364.741455  254321219Y002368
# 4     29915626.0       113446188    1.050523   88681119P000020
#
#   Tanggal datang kunjungan FKTP Tanggal pulang kunjungan FKTP  Provinsi FKTP
# 0                    2019-08-01                    2019-08-01             61  \
# 1                    2020-06-17                    2020-06-17             51
# 2                    2019-06-01                    2019-06-01             35
# 3                    2019-12-21                    2019-12-21             34
# 4                    2019-11-04                    2019-11-04             35
#
#    Kabupaten/Kota FKTP  Kepemilikan FKTP  Jenis FKTP  ...
# 0                 6108                 3           1  ...  \
# ...

# %%
# Cek jumlah data
df.shape
# Out:
# (4056898, 26)

# %%
# cek jumlah data setiap kolom
df.count()
# Out:
# Nomor peserta                                       4056898
# Nomor keluarga                                      4056898
# Bobot                                               4056898
# ID Kunjungan FKTP                                   4056898
# Tanggal datang kunjungan FKTP                       4056898
# Tanggal pulang kunjungan FKTP                       4056898
# Provinsi FKTP                                       4056898
# Kabupaten/Kota FKTP                                 4056898
# Kepemilikan FKTP                                    4056898
# Jenis FKTP                                          4056898
# Tipe FKTP                                           4056898
# Tingkat Pelayanan FKTP                              4056898
# Jenis Poli FKTP                                     4056897
# Segmen Peserta saat akses layanan FKTP              4056898
# Kode dan nama diagnosis ICD 10 (3 digit)            4056898
# Kode diagnosis ICD 10 (3 digit)                     2676657
# ...

# %%
# cek kolom kode diagnosis ICD 10 (3 digit) dan tampilkannya
df['Kode diagnosis ICD 10 (3 digit)']
# Out:
# 0          NaN
# 1          K29
# 2          Z30
# 3          I10
# 4          I11
#           ...
# 4056893    NaN
# 4056894    H26
# 4056895    NaN
# 4056896    K30
# 4056897    NaN
# Name: Kode diagnosis ICD 10 (3 digit), Length: 4056898, dtype: object

# %%
# Cek null value pada setiap kolom
df.isnull().sum()
# Out:
# Nomor peserta                                             0
# Nomor keluarga                                            0
# Bobot                                                     0
# ID Kunjungan FKTP                                         0
# Tanggal datang kunjungan FKTP                             0
# Tanggal pulang kunjungan FKTP                             0
# Provinsi FKTP                                             0
# Kabupaten/Kota FKTP                                       0
# Kepemilikan FKTP                                          0
# Jenis FKTP                                                0
# Tipe FKTP                                                 0
# Tingkat Pelayanan FKTP                                    0
# Jenis Poli FKTP                                           1
# Segmen Peserta saat akses layanan FKTP                    0
# Kode dan nama diagnosis ICD 10 (3 digit)                  0
# Kode diagnosis ICD 10 (3 digit)                     1380241
# ...

# %%
# isi kolo null dengan 0
df.fillna(0)
# Out:
#          Nomor peserta  Nomor keluarga       Bobot ID Kunjungan FKTP
# 0          157978748.0        50765420   20.064983         958073632  \
# 1           95085112.0        26931775    2.626307  449590620P000054
# 2          224470578.0       227368233    1.051830  467490619P000001
# 3           63871289.0        62313678  364.741455  254321219Y002368
# 4           29915626.0       113446188    1.050523   88681119P000020
# ...                ...             ...         ...               ...
# 4056893    212666736.0        91270403   14.246229        1285820875
# 4056894     30859241.0        30859241    3.886934  315641120P000514
# 4056895      8859416.0         8859416    6.146070         962412926
# 4056896    399491834.0       399491834   26.548826  273170420P000003
# 4056897     99146724.0        39321920   88.348953        1188955927
#
#         Tanggal datang kunjungan FKTP Tanggal pulang kunjungan FKTP
# 0                          2019-08-01                    2019-08-01  \
# ...

# %%
# drop kolom yang memiliki null value
df.dropna()
# Out:
#          Nomor peserta  Nomor keluarga       Bobot ID Kunjungan FKTP
# 1           95085112.0        26931775    2.626307  449590620P000054  \
# 2          224470578.0       227368233    1.051830  467490619P000001
# 3           63871289.0        62313678  364.741455  254321219Y002368
# 4           29915626.0       113446188    1.050523   88681119P000020
# 5          189355720.0        69855169   30.044949   97010720P000238
# ...                ...             ...         ...               ...
# 4056888     24766757.0        44813505   16.388153   25380419Y000191
# 4056889     83240705.0        59440736   74.271950   40461119P000771
# 4056891     40295955.0        40295955  162.410797  257350819Y001095
# 4056894     30859241.0        30859241    3.886934  315641120P000514
# 4056896    399491834.0       399491834   26.548826  273170420P000003
#
#         Tanggal datang kunjungan FKTP Tanggal pulang kunjungan FKTP
# 1                          2020-06-17                    2020-06-17  \
# ...

# %%
# cek jumlah data null pada kolom Kode diagnosis ICD 10 (3 digit)
df['Kode diagnosis ICD 10 (3 digit)'].isnull().sum()

# drop kolom yang memiliki null value
df.dropna(subset=['Kode diagnosis ICD 10 (3 digit)'])
# Out:
#          Nomor peserta  Nomor keluarga       Bobot ID Kunjungan FKTP
# 1           95085112.0        26931775    2.626307  449590620P000054  \
# 2          224470578.0       227368233    1.051830  467490619P000001
# 3           63871289.0        62313678  364.741455  254321219Y002368
# 4           29915626.0       113446188    1.050523   88681119P000020
# 5          189355720.0        69855169   30.044949   97010720P000238
# ...                ...             ...         ...               ...
# 4056888     24766757.0        44813505   16.388153   25380419Y000191
# 4056889     83240705.0        59440736   74.271950   40461119P000771
# 4056891     40295955.0        40295955  162.410797  257350819Y001095
# 4056894     30859241.0        30859241    3.886934  315641120P000514
# 4056896    399491834.0       399491834   26.548826  273170420P000003
#
#         Tanggal datang kunjungan FKTP Tanggal pulang kunjungan FKTP
# 1                          2020-06-17                    2020-06-17  \
# ...

# %%
# cek hubungan antar kolom menggunakan grafik
df.plot(x='Kode diagnosis ICD 10 (3 digit)', y='Kode diagnosis (beragam 3-5 digit)', style='o')
plt.title('Kode diagnosis ICD 10 (3 digit) vs Kode diagnosis (beragam 3-5 digit)')
plt.xlabel('Kode diagnosis ICD 10 (3 digit)')
plt.ylabel('Kode diagnosis (beragam 3-5 digit)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # cek hubungan antar kolom menggunakan grafik
# ----> 2 df.plot(x='Kode diagnosis ICD 10 (3 digit)', y='Kode diagnosis (beragam 3-5 digit)', style='o')
#       3 plt.title('Kode diagnosis ICD 10 (3 digit) vs Kode diagnosis (beragam 3-5 digit)')
#       4 plt.xlabel('Kode diagnosis ICD 10 (3 digit)')
#
# File c:\Users\ariop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\ariop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
# ...
